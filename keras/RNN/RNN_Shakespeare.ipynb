# %% [markdown]
# ### Shakespearian character-level RNN model

# %%
from __future__ import print_function
import sys
import numpy as np
import re
import random
import pickle

from nltk.corpus import gutenberg

from keras.models import Sequential
from keras.layers import Dense, Bidirectional, Dropout
from keras.layers import SimpleRNN, GRU, BatchNormalization

from keras.callbacks import LambdaCallback
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# first time: download gutenberg with python and nlt.download('gutenberg')
hamlet = gutenberg.words('shakespeare-hamlet.txt')   # Ordered list of words in Hamlet

print(hamlet[:10])
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', 'William', 'Shakespeare', '1599', ']']

# %%
# lowercase all words

text =''

for word in hamlet:            
    text+=str(word).lower()   
    text+= ' '                 
    
    
print('Corpus length, Hamlet only:', len(text))
# Out:
# Corpus length, Hamlet only: 166765

# %%
'''
Break text into :

Features  -    Character-level sequences of fixed length        
Labels    -    The next character in sequence     

'''

training_sequences = []          # Empty list to collect each sequence 
next_chars = []                  # Empty list to collect next character in sequence
seq_len, stride = 35, 1          # the input sequence will be 35 chars long, and the window moves by 1 char each time


for i in range(0, len(text) - seq_len, stride): 
    training_sequences.append(text[i: i + seq_len]) 
    next_chars.append(text[i + seq_len])

# %%
# Print out sequences and labels to verify

print('Number of sequences:', len(training_sequences))
print('First sequences:', training_sequences[:1])
print('Next characters in sequence:', next_chars[:1])
print('Second sequences:', training_sequences[1:2])
print('Next characters in sequence:', next_chars[1:2])
# Out:
# Number of sequences: 166730
# First sequences: ['[ the tragedie of hamlet by william']
# Next characters in sequence: [' ']
# Second sequences: [' the tragedie of hamlet by william ']
# Next characters in sequence: ['s']

# %%
# Get sorted list of unique characters in hamlet

characters = sorted(list(set(text)))
print('Total characters:', len(characters))
# Out:
# Total characters: 43

# %%
# Make lookup dictionaries to map each unique charatcer with an integers
# for training purposes

char_indices = dict((l, i) for i, l in enumerate(characters))
indices_char = dict((i, l) for i, l in enumerate(characters))

print(char_indices)
# Out:
# {' ': 0, '!': 1, '&': 2, "'": 3, '(': 4, ')': 5, ',': 6, '-': 7, '.': 8, '1': 9, '5': 10, '9': 11, ':': 12, ';': 13, '?': 14, '[': 15, ']': 16, 'a': 17, 'b': 18, 'c': 19, 'd': 20, 'e': 21, 'f': 22, 'g': 23, 'h': 24, 'i': 25, 'j': 26, 'k': 27, 'l': 28, 'm': 29, 'n': 30, 'o': 31, 'p': 32, 'q': 33, 'r': 34, 's': 35, 't': 36, 'u': 37, 'v': 38, 'w': 39, 'x': 40, 'y': 41, 'z': 42}

# %%
#Create a Matrix of zeros
# With dimensions : (training sequences, length of each sequence, total unique characters)
# 3 dimensions because it's one-hot encoded (double letters do not matter here)
x = np.zeros((len(training_sequences), seq_len, len(characters)), dtype=np.bool)
y = np.zeros((len(training_sequences), len(characters)), dtype=np.bool)


for index, sequence in enumerate(training_sequences):     #Iterate over training sequences
    
    for sub_index, chars in enumerate(sequence):          #Iterate over characters per sequence
        
        x[index, sub_index, char_indices[chars]] = 1      #Update character position in feature matrix to 1
        
    y[index, char_indices[next_chars[index]]] = 1         #Update character position in label matrix to 1

# %%
print('Data vectorization completed.')
print('Feature vectors shape', x.shape)
print('Label vectors shape', y.shape)
# Out:
# Data vectorization completed.
# Feature vectors shape (166730, 35, 43)
# Label vectors shape (166730, 43)

# %%
# Simple 1-layered RNN with 128 neurons

def SimpleRNN_model():
    model = Sequential()
    model.add(SimpleRNN(128, input_shape=(seq_len, len(characters))))
    model.add(Dense(len(characters), activation='softmax'))
    return model

# %%
# Two stacked RNN layers, both with 128 neurons

def SimpleRNN_stacked_model():
    model = Sequential()
    '''
    return_sequences allows the RNN to output the array of predictions, one per time step,
    instead of only the last prediction. This is useful in stacking RNNs
    return_sequences has to be false on last layer (for classification)
    '''
    model.add(SimpleRNN(128, input_shape=(seq_len, len(characters)), return_sequences=True))
    model.add(SimpleRNN(128))
    model.add(Dense(len(characters), activation='softmax'))
    return model

# %%
# Two stacked GRU layers with 128 neurons each

def GRU_stacked_model():
    model = Sequential()
    model.add(GRU(128, input_shape=(seq_len, len(characters)), return_sequences=True))
    model.add(GRU(128))
    model.add(Dense(len(characters), activation='softmax'))
    return model

# %%
# Two stacked bi-directional layers with 128 neurons each
# a bidirectinal gru processes the data in both the normal and the reverse sequence
# the output formula is y_t = g(W_y*[a_t, a_rt] + b_y)
# The activation and weight matrices here are simply defined by the model nested within the bi-directional layer.
def Bi_directional_GRU():
    model = Sequential()
    model.add(Bidirectional(GRU(128, return_sequences=True), input_shape=(seq_len, len(characters))))
    model.add(Bidirectional(GRU(128)))
    model.add(Dense(len(characters), activation='softmax'))
    return model

# %%
# Large GRU model with 3 GRU layers and one densely connected hidden layer, using dropout strategy
# the recurrent dropout shuts down the same neurons at each time step, otherwise too much info would be lost

def larger_GRU():
    model = Sequential()
    model.add(GRU(128, input_shape=(seq_len, len(characters)),
                       dropout=0.2,
                       recurrent_dropout=0.2,
                       return_sequences=True))
    
    model.add(GRU(128, dropout=0.2,
                  recurrent_dropout=0.2,
                  return_sequences=True))
    
    model.add(GRU(128, dropout=0.2,
                  recurrent_dropout=0.2))
    
    model.add(Dense(128, activation='relu'))
    
    model.add(Dense(len(characters), activation='softmax'))
    
    return model

# %%
# All defined models

all_models = [SimpleRNN_model,
              SimpleRNN_stacked_model,
              GRU_stacked_model,
              Bi_directional_GRU, 
              Bi_directional_GRU,
              larger_GRU]

# %% [markdown]
# ### Sampling tresholds
# By introducing some randomness in the selection of the next character, the model can 'experiment' new routes and come out with new novel sequences, instead of just replicate the ones in the training set.

# %%
# Sampling a character index from a probability array
'''
weighted randomness: instead of choosing the char with most probability out
of the softmax, the model could chose even others, with a probability equal to the char 
probability out of the softmax.
The treshold determinates the randomness: the higher, the more random is the output.
'''

    
def sample(softmax_predictions, sample_threshold=1.0):
    
    softmax_preds = np.asarray(softmax_predictions).astype('float64')    # Make array of predictions, convert to float
    
    log_preds = np.log(softmax_preds) / sample_threshold                 # Log normalize and divide by threshold
    
    exp_preds = np.exp(log_preds)                                        # Compute exponents of log normalized terms
     
    norm_preds = exp_preds / np.sum(exp_preds)                           # Normalize predictions
    
    prob = np.random.multinomial(1, norm_preds, 1)                       # Draw sample from multinomial distribution
    
    return np.argmax(prob)                                               #Return max value

# %%
# Callback Function executed epoch end, generates Prints 
'''
This function will take a random sequence of characters from the Hamlet text
and then generate 400 characters to follow on, starting from the given input
'''
def on_epoch_end(epoch, _):
    global model, model_name
    
    print('----- Generating text after Epoch: %d' % epoch)
    
    start_index = random.randint(0, len(text) - seq_len - 1)    # Random index position to start sample input sequence
    end_index = start_index + seq_len                           # End of sequence, corresponding to training sequence length
    
    sampling_range = [0.3, 0.5, 0.7, 1.0, 1.2]                  # Sampling entropy threshold
    
    for threshold in sampling_range:
        print('----- *Sampling Threshold* :', threshold)
        
        generated = ''                                          # Empty string to collect sequence
        
        sentence = text[start_index: end_index]                 # Random input sequence taken from Hamlet
        generated += sentence                                   # Add input sentence to generated
        
        print('Input sequence to generate from : "' + sentence + '"')
        
        sys.stdout.write(generated)                            # Print out buffer instead of waiting till the end
        
        
        for i in range(400):                                   # Generate 400 next characters in the sequence
            
            x_pred = np.zeros((1, seq_len, len(characters)))   # Matrix of zeros for input sentence
            
            for n, char in enumerate(sentence):                # For character in sentence
                
                x_pred[0, n, char_indices[char]] = 1.          # Change index position for character to 1.
                
            preds = model.predict(x_pred, verbose=0)[0]        # Make prediction on input vector
            
            next_index = sample(preds, threshold)              # Get index position of next character using sample function
            
            next_char = indices_char[next_index]               # Get next character using index
            
            generated += next_char                             # Add generated character to sequence (length stays the same)
            sentence = sentence[1:] + next_char
            
            sys.stdout.write(next_char)
            sys.stdout.flush()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
def test_models(list, epochs=10):
    global model, model_name
    
    for network in list:   
        print('Initiating compilation...')
        
        # Initialize model
        model = network()
        # Get model name
        model_name = re.split(' ', str(network))[1]  
        
        #Filepath to save model with name, epoch and loss 
        filepath = "./models/versions/%s_epoch-{epoch:02d}-loss-{loss:.4f}.h5"%model_name
        
        #Checkpoint callback object 
        checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
        
        # Compile model
        model.compile(loss='categorical_crossentropy', optimizer='adam')
        print('Compiled:', str(model_name))
        
        # Initiate training
        network = model.fit(x, y,
              batch_size=100,
              epochs=epochs,
              callbacks=[print_callback, checkpoint])
        
        # Print model configuration
        model.summary()
           
        #Save model history object for later analysis
        with open('./models/history/%s.pkl'%model_name, 'wb') as file_pi:
            pickle.dump(network.history, file_pi)

# %%
test_models(all_models, epochs=5)
# Out:
# Initiating compilation...
# Compiled: SimpleRNN_model
# Epoch 1/5
# 166730/166730 [==============================] - 15s 91us/step - loss: 2.2316
# ----- Generating text after Epoch: 0
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "clown . giue me leaue ; heere lies "
# clown . giue me leaue ; heere lies , and the mand , the sould the sing , in this loue tha ke the pare , the sithe se the the king , the her . in the wath the south you mast ou he wert , and will my lord , the tha la de me the kenge mad the se the lathe se the me me the me loue the se be the singe , and the se the the me the lathes make the the haul the seall our . what the this se for in the me hea . so the healle , whe s aple , th----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "clown . giue me leaue ; heere lies "
# clown . giue me leaue ; heere lies , ind dor . ald don . in an the par ham . the hail bot vy lo m it the sing , my lord , mo vs are the me , ard and the llours ond his the mant , of whes of you gathe ther vnol the mashe the ke cous , tho fwell the far . whald ing our of hom . what ham . the se her ' t of ous no d an the dore , of is my loud : the mante go be sind ham . wor ' d beamy ham . o me theme ser the his , the seate the bes ----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "clown . giue me leaue ; heere lies "
# clown . giue me leaue ; heere lies pishi pyras couke weold sher , whe de hes yos dperis : the sie t ou d the way som . is fure the wathe s mach in ' che tham . il the ferdeste ; che daue the pane ou s of ' the sharke li ham . whate siond sof ther wolld ' d oue him . th ber at stis , the the ghol the dinget spele mo her has . it his this hamlit , th ake wieris quense , t ar ' t me beer , on thid hit vamy the merd , blt your theu chi----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "clown . giue me leaue ; heere lies "
# clown . giue me leaue ; heere lies , aduthemyee coplo vrt; ghylle shes dige swy thin qpisla diso ho feine midl :ne muct by w you mar haneepto gto hit llay toop cathouss the celaswin ake vsagice geound , vndispe , os sa ne minke . wosteo thes out chis : sue whast is tanthe if : hem , wed se , thet sa vauds the ght whand s if the oas fond d ap ' th thele , ghawn wice mon op m praless she or merime kipll ofre , ldor . mate ghos if y m----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "clown . giue me leaue ; heere lies "
# clown . giue me leaue ; heere lies . roteofllyed wagly the wawer akie : ffe tiin , of fad ofe weeser the hee ltyd ohe wpaem; dxrpmord heplates ' st is : goy dienceraos ? bn mbph bedte . so tin vi , besf la do thins com mishe t wbelle ? fipe , medt yow vnwnegh bepce thundosame maml r?le vpeplee 'id bbe hace fnot pety tsi largope. feith youey , make wiil bis dhued you hinz wich wnake tmy lotd nos thbllowd ; coly bouady , baausnto ? hEpoch 2/5
# 166730/166730 [==============================] - 15s 90us/step - loss: 1.9586
# ----- Generating text after Epoch: 1
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "hat , which foure successiue kings "
# hat , which foure successiue kings , and the she . our mase of his a doue the father , and the porse ous loue the the has . ham . i haul the sange , and in the seaue and loue , and the mase of hour whe the the weare , and the seaue the the mond , the seare , and the and of hould , and the pay , and ham . he ham . a the ham . what has ham . that is the fore , and well the ding . the with and lore the weele son . the made , and the ,----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "hat , which foure successiue kings "
# hat , which foure successiue kings mare ma soull , and the pance or haull the peand be me . make ham . my lord , and the visue to the is you the stake a thou ' s of my loue , and and , the sing , and of lath hath the sere ? hour the hasd of ham . what we the heane , and the soue le do mond and has . me the haue the mande the mare ve pockeno . on mere the and , and the foule ham . i wild and loud , and greaue the deare the hiugh a d----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "hat , which foure successiue kings "
# hat , which foure successiue kings wee - har . i ting laue - make sreine . make of in thes fach il some that mon . m bett be of the co mor . shet ole buthe , thay he fither : so round be mish whald he rade , in estere , the kende hes ponde houe the vn thim wond , you the houe nith hand to the  ore count , ffore , and for weas an se the thou hin wist of the father , ghoul seacl ham . whe way io thy conowill : hom . a din the camant ----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "hat , which foure successiue kings "
# hat , which foure successiue kings mo iesi goome ou myer . the are the rauech : loue ham . ow you se tenth nnthrowt mo donde anathe langnoes de pait to aul , to thoue hott all hesule : aul ' d thon . you houge il o burgue ) askinge s aad . dos e more you thourg of fores aue lard . oo murdee afre the wind of blas the wind cathi t eathors as hta hing wis ee t ol ' tnd and mye loue aule shom ve pand you miss wonce ne me a toow , wall ----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "hat , which foure successiue kings "
# hat , which foure successiue kings is in est casce his pand freine hnueds kant ; , whe lay hem . wfoxin y thats if wings tond iuglabe ' rce io ? artweltis tree you hous matewe ghee ) io cryouls bukm ham it theuecone ofse ander manctt rme dna betre inntird fhace hiu . notrelll- : whetepaescy : fhoue wellptasw frethaboh ane and vilne . your dace om' gealeod at kald wxognt ho desce scale ' t oppe : thit it ' sribep fome , th mad dee bEpoch 3/5
# 166730/166730 [==============================] - 15s 90us/step - loss: 1.8553
# ----- Generating text after Epoch: 2
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : " the poor be flatter ' d ? no , let"
#  the poor be flatter ' d ? no , let the seane heare and mant the pand to the peate , that is the doust of the singe so not , and gith this the come to the pray of the could ham . the mand sine , be the soust of the stien the sing to the keng the that the stall the cond ham . what is the mand the more the mert will so the mart the the mant the mand the the send with me to the cound so not do not the then the seane to the se the the ----- *Sampling Threshold* : 0.5
# Input sequence to generate from : " the poor be flatter ' d ? no , let"
#  the poor be flatter ' d ? no , let that ended ham . a my lath sel and do not the soue the cost of sact of lither seane do ham . i dis the goode and bean shar shat the king to this the cousce and thend a dinge sith i mart ; far to not do not has then that ind his tie good and speake to in gure fur he the grod more to did the mand the ill of the sille ste coued me dee the mend then the kend my lord , for the dis them and the me pare----- *Sampling Threshold* : 0.7
# Input sequence to generate from : " the poor be flatter ' d ? no , let"
#  the poor be flatter ' d ? no , letse ping now son . that wind . gue thy doue youe ind dorowie ; and thea do , the potmen giuer , thit sall it thaur such the the chourd besterng ham . this man dis my madine , our sigite te that makl to that vn the my morkee : i bnuerte glo krow we chouch of ile non the pray the beds that bre then sich my tay har . so . swert weare with dey lestenct to hee king . exertiffard inde you to do this comm----- *Sampling Threshold* : 1.0
# Input sequence to generate from : " the poor be flatter ' d ? no , let"
#  the poor be flatter ' d ? no , let nog iurseaue er ham . i wouds ou ) the sent is beace : are hingale a kinm . glastsss to ke no your pyoline mast my lord ' t wien to hil ' s inded and me ourd ortures not on vneant ele , nos , then she dee guit , and greaches debct ol offee no houds , sisy doue pike comed your aul bidse comatther ( my comwat ? kinh torne , ther dimes of peament fay bethst wathers your be thy dodeent ' d ? inas ofl----- *Sampling Threshold* : 1.2
# Input sequence to generate from : " the poor be flatter ' d ? no , let"
#  the poor be flatter ' d ? no , let endry faidint acr bed , es murtiue nor slather sayees do natel s ay my sagl wit vply mosh diy mald east ( pely a ' or ' s heay : vsto king . qu . ace til in tiot vbteunitw pow , sfeacowas whithtinoughne : as now : teee spyel ' r brawitkence oth onines thitkry watt bed me -eles detitell abr kants you  ofr it letewes & sint bebdull to : irw hrselild sep hes fay you hear gathard , and siscestll cetrEpoch 4/5
# 166730/166730 [==============================] - 15s 89us/step - loss: 1.7819
# ----- Generating text after Epoch: 3
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "herod ' s herod . pray you auoid it"
# herod ' s herod . pray you auoid it is his fore , and my lord , and it he well is not be well . the hambet the the hame the well my lord , with the winde , and gite the hamlet ham . i haue the winds , and he heare , and the pare , and in the hame the peather his shall the beane , the weare , and ham . the the hame the hame the hame the hame the with the was ham . ham . the wind the growne , and the wis the gaues , that is is my lor----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "herod ' s herod . pray you auoid it"
# herod ' s herod . pray you auoid it is is is he maken that vngare : he wor ham . will a soule , and that i haue the guild , thene with nor as no my lord ham . the the with the ereand , and dis the in in foure in is in my sorde , bun the that no has he se shere his reanes and more the haue , with the rower , and hame the ersine . and not the ham . not the what pray you his as in mand the the my lord , him my lord hamlet hit your hee----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "herod ' s herod . pray you auoid it"
# herod ' s herod . pray you auoid it he wno dy goune , and in whle slathis of coustion , the ind in me well my lord , to , wist to thad her ? hy would houes hamlet the wargh light heares . the mare , go selie , haday in the eangrse ering teish with he that well is netued him . in mastie with no most falles feame . ne the ' d can in this froles , vn mo the se : and not uer you not net the mirt the groone the haue ham . wis my lownes ----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "herod ' s herod . pray you auoid it"
# herod ' s herod . pray you auoid it wouth thay no stime sheee , that y , at hee asseririe cllams sthanerith on me same of nackes vn hiphetiarur . hat and thas me the hae hrant you cope inh his craitetieg queenthe remengures , and we haue not fray how sthertirn giue , and my sowne that i sartestrush . he whild blaintie did the ge fratioune a and on sis your writhts , good thou his howeely that i his lan , foo his rufoas . ice thay a----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "herod ' s herod . pray you auoid it"
# herod ' s herod . pray you auoid it theo , you berefsine in poust , me , to thy besim ' d in your bitit know steintis hearine plabewreed has drinkem ; the plobbunte , lnost yours fondetie . - goostain tha gablo the vosay hiu shered ham . vpant his my letibn vnsay doe shelte is my by hemaridd morast nit . oy heenas ? homeelite might chniocie grigplbyer ou poosenth yit secersinged it wause it tyal sucati, wnsse oshy . tam htice , metEpoch 5/5
# 166730/166730 [==============================] - 15s 90us/step - loss: 1.7284
# ----- Generating text after Epoch: 4
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : " that it vs befitted to beare our h"
#  that it vs befitted to beare our heare to the seant , the wast the sore , the this a dost the sore , the lore , the mert me to selfe the shere mart for the shall to the the seane , the there , and the seant , the seare , and it the this forme , the sense of the sare to se frat the seane , and the sall the that i haue a do the mart the selfe , and the seruer , and the sone to his to the serse , and the sere , the se fort the seater----- *Sampling Threshold* : 0.5
# Input sequence to generate from : " that it vs befitted to beare our h"
#  that it vs befitted to beare our head he the songer . the marre there , i lane hem and me to the conster ' d you may thes inse : the the king , and the she this ham . i his lay the serare hee this mart , and the selfe to tile hor . i do the seaue to the sones some in the seant the beare , to gue to stert sead my lord , which i ' th ' tis see to the sporse you and to her . a dand , the faine the more ham . i the pray lith the sare ----- *Sampling Threshold* : 0.7
# Input sequence to generate from : " that it vs befitted to beare our h"
#  that it vs befitted to beare our har . i more , ther ' s , to the thot couss and most me selfe bronoued verine me ? hur and the ligend it sefore the kind to to not thong will to the sounce not be to her bus me then mode this heare , the vnerme , as it from her the ofe dees , you my , and then dayts and dee no strost detent your pucame inder ' l the some the more no hase , or sull the sall sime ; whet ow me beadon mose forme sse , ----- *Sampling Threshold* : 1.0
# Input sequence to generate from : " that it vs befitted to beare our h"
#  that it vs befitted to beare our hear , i kno . your for ' n iule cutlen exipere on ho . i ame the grued frr . row bure thee ? ard meine ome , you goe seeres goifelle the seare king . exe not you ase misint way king . go to vprod tian ; the , wath you haun the tide to beft : corculement on my surke , br night be botit , to for con you and by is ducke well , to not becin ' d to mony as . lord , it be cristeace his shioke to that ca----- *Sampling Threshold* : 1.2
# Input sequence to generate from : " that it vs befitted to beare our h"
#  that it vs befitted to beare our hiubpstion ? bounmine ; is ? for nor thre , no ? lot irt be minst : so ip querne he mond fich now the meeroton io is deant yout letaee ofies me nowir , and lare hix caase and bickeriald , wilt let deny you : lee expong raclecke or hum . i marny thy droush . you not my thill m ' m . oure you dout a - sfoyele mire so foturation the mest wile io , duin we , tho hupbliog of pracome tuit muse of mursiou_________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_4 (SimpleRNN)     (None, 128)               22016
# _________________________________________________________________
# dense_4 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 27,563
# Trainable params: 27,563
# Non-trainable params: 0
# _________________________________________________________________
# Initiating compilation...
# Compiled: SimpleRNN_stacked_model
# Epoch 1/5
# 166730/166730 [==============================] - 29s 176us/step - loss: 2.1360
# ----- Generating text after Epoch: 0
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : " higher rate , then a command to pa"
#  higher rate , then a command to pan . what the me the lend , and whold the the now the she me , that the manter , her . i ham . what ham . whe not be the salle , the prowes , and the manter . the me the manter , and the store , and the store , the me the mange , and the me the prower , who the meare the mane : for with the plower , and the solle . i hau . whe will the my mord , the rust , the shaue the mane the minge , that the so----- *Sampling Threshold* : 0.5
# Input sequence to generate from : " higher rate , then a command to pa"
#  higher rate , then a command to pance , the , the whe foranes , the reame the singe the praune , the sentinn the lore . a morte the lous , an what , what you soll : the whing the soull : the mare him . whe of my meater , her for . do ' d the kinge , the loring : the plow the me , that : what fer me mareath of merter , a would her . the propense , will there an the ham . o make of this for brat , be the not , pele it the pane , fil----- *Sampling Threshold* : 0.7
# Input sequence to generate from : " higher rate , then a command to pa"
#  higher rate , then a command to parte the for . wher as ing fere , sthe poll , him . i wile , and me a houre on make ; a the hamtese . now that heruense ; you selor what : it thice io i the make of the fente , be lis mill the . win the noppllay hersing winkengs of ham . i thas that to me siater , and you doous thy sorond he be fiols : on ' thed this thy feare , the make in the parse seluer i whoue sham . that , sham . why thau ; i----- *Sampling Threshold* : 1.0
# Input sequence to generate from : " higher rate , then a command to pa"
#  higher rate , then a command to pal gome the forre . lee : his of tike mowhuli ster whawhttente an , not tithing anding , hamyeu ' d shy shauen the weimer se vikim . thes are . be pe bthe , at hor our leing goobd ; o thom thebs arm to - pukmce to thre makte fan him s awle ; sheadest , hamlea troust , mrigkengos lor ) fake ; anz theue hherme tit ham . pke pilas you siplstime plr scisens , if nelle daud , to thor wonthelle ie hornes----- *Sampling Threshold* : 1.2
# Input sequence to generate from : " higher rate , then a command to pa"
#  higher rate , then a command to paparowoql say nco enceeld whenetsingro de our ' r a lales be buiesedse . aze thes : obree king arist . to ferot , you my mosner ofle hix vway so vsse reabtombes aue an bthnd your byouge , wporth , burnost folsuston , bulese . angit : hamde chelded on my , be anmentorsuall o herduyngr fpides for wptike hom do - chfires ey yead ; ilas bles . so gacliterausizt in of rueld de rocasow too dof ' t thouerEpoch 2/5
# 166730/166730 [==============================] - 29s 174us/step - loss: 1.8005
# ----- Generating text after Epoch: 1
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : ": for they say , an old man is twic"
# : for they say , an old man is twicke the stor in the king . and the still . a there the stouth , and the manter , and the deare a seake the say , and thes the that i saue i part , i haue the doue in the prowher . the seene that ' t , the king . the soule to see , and the king . the pars to the king . the that shall there ham . i and the pore in the still , that i haue the with a stor the seere , and the sence and loue , the seene ----- *Sampling Threshold* : 0.5
# Input sequence to generate from : ": for they say , an old man is twic"
# : for they say , an old man is twickes , that a froment , and the deen crowce , shere as houe senint , i haue heare to seaues a feare as of this poue your parse , and there you grow in the virt what grouse a coulond lard , there whered me to the mint , to the king . oh the forsesse in the king . and this mest , and why maue to the waste , and it is the haue the know ' d haue ham . i and the farthing . oh the and then hamlet of this----- *Sampling Threshold* : 0.7
# Input sequence to generate from : ": for they say , an old man is twic"
# : for they say , an old man is twickis , and gord , and that is houle or the pangoun thew thes is the stings , thou then the meares , and letth , but deaue , i haue the gennes , restient louen , and there tir deanes to they the stor wigh and to vnow there ham . i obre . ' the toue these and part , that i haue your prpsies , aterne and werth there these this praich of there wand your toone , the bent , and detsharied . it ofor to th----- *Sampling Threshold* : 1.0
# Input sequence to generate from : ": for they say , an old man is twic"
# : for they say , an old man is twickes ' d let mongharle dauicath laue , therpaly mruenine ; selfe loue that hearestower , iueleer queptes thenich s a haue in audie thou stelfery hamdell - whemedine honker , frocken mouinterts a syebthall gones neis feagh soowhre from is thour by , whoph ather hirsw you are the king : in by thow you falles , oranghs ofould ince an are loue to weauen , onos nor thar : it by fey to thee , vconith ' d----- *Sampling Threshold* : 1.2
# Input sequence to generate from : ": for they say , an old man is twic"
# : for they say , an old man is twicke speay heartes fege ofuericinge ineyaue . to my to deare wamloud agyolars once stres - lork; clafye taue exsteriny to deary , anout ? hig mustce that s[ates t, fakles me tringe quweruie bupodsanth hamesties be haue wall weauy , i see re ofs burd acki tapy tien ' striug senfert korgnowinyncnowing vurt nor . prouse , engha brie andepralieine kin hey arrancole dremles , houll - ander : to theued ' Epoch 3/5
# 166730/166730 [==============================] - 29s 174us/step - loss: 1.6826
# ----- Generating text after Epoch: 2
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "ancy , he hath borne me on his back"
# ancy , he hath borne me on his backe , but i haue my lord , and lord ham . he deere he see , the did ham . i may be so my lord , and he fande , the deare , and it ham . i may the matte , and heere the beaues , and with me see , i dine , and be of a sellenger , and in the marre , and he day , and bother , and his good me . as it my lord , and the mar . farre ham . i say , and haue he deaue , the madnes , and my lord , and my lord ha----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "ancy , he hath borne me on his back"
# ancy , he hath borne me on his backe to my lord , you the prayes all ham . i am the mayte the raue her say , he may be soule , fore while so my lord , and what is , and my lord , no marke ham . that it beaye , for the courte vnclitie , my lord , encelfe the mad , and his is my lord , i will , but sorang , so my lord , and the make , i haue not so , where the must lord , you seare and viries me not ham . i well , and mady thy is , a----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "ancy , he hath borne me on his back"
# ancy , he hath borne me on his backe , she deere he me doue to , loth dither , but you dir not my lordsilles our , castime , and he me to caineto marneting , and the mayer be madnesse his to ' s nith clesse . hy lord hast be wistranger . and me not to rearth , and with you that me his latserungem ham . scanes , peadilles a giune my liue : oh my sir , you be all phache , my lord , resires my liue , this beure our wellarde my lord , ----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "ancy , he hath borne me on his back"
# ancy , he hath borne me on his backenceane , my gooth grordicke in this gose angar . my lord , ilenpor by lord ham . polaines ganspreine had as and forke hee exeraly how you stofled ; qugenpe of dory , me nade dead tiw ingestriesso me time , and selfe pray 1ue ham . indee fer my staly seeke thines lime . coue pon . cateonerre it o harries i wall of eid , nime my lend ' stone , ice maue impe . goirtoust , who mid you pesand guilne '----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "ancy , he hath borne me on his back"
# ancy , he hath borne me on his backint , my lord my hym . bold i hither qumard colfuondemost the kins all ' tishensemasher ? gose laie agdacountallem ? kidse abminther heare with if irgetur inctacince , law is old no leriuing , with me nosinesselfiugwoll hinde , shal. , sot ewlenter forteby all made - you scill you withell , you aleorrong me betweros anpute , yeakor fontrifiss speeneldongerfy to , i roygur vande my fet mlemerne : kEpoch 4/5
# 166730/166730 [==============================] - 29s 174us/step - loss: 1.6154
# ----- Generating text after Epoch: 3
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "s ; if this be otherwise , if circu"
# s ; if this be otherwise , if circule so the very songer , and mart the gree in this stone , and the man the polon . vpon the mannes , the man it is the vire the pray , the man it not the mont the donge , the man it some so not the still so not with the man the good , the king , and with make these the propes , the deare the poore , the word , the verte , and to the fall be shall shall will not the good , and mare it the selfe , th----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "s ; if this be otherwise , if circu"
# s ; if this be otherwise , if circuing , and more not the part , and let me to sist not in the dome , and loue for owne a like the night , the bland the downe , for he this was my lord , and gard , the priches he man is this part , that ' s to the will the wance , and the pold polition , the polse in the propers , and not this in the word ham . this the manter , the with a crow , so make this more , what mar . the ranger ' d , i wi----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "s ; if this be otherwise , if circu"
# s ; if this be otherwise , if circunt in beare the tirlon , will is be , and to this hatthith , i speene , one the gant you this parching : but king , the parting do say cannet tay isw sing indeeme of deere of this natthis ophe . so make , would this nempins , that day to the in some so shall so me ? it your fat , with fare , exe will is no word , the crownous of nermes , ald say me sir . and fanderall forme : for be vne the thinke----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "s ; if this be otherwise , if circu"
# s ; if this be otherwise , if circuly lird , and will not me . fortes vny , nofferas the goes is cla tonow a nowne and dods ? weementer with verfeem may , giuls gaines my seenes , the king , an this shr ' d tsilt king ond faithing regen oouch , for he mayse alextiuell kingse with cemes ? rannes , nor mughis ) who king my lord ? is in bar . gho . where weld vlocinius mare , the very without , giuengy and frong you ? resim roygull ti----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "s ; if this be otherwise , if circu"
# s ; if this be otherwise , if circulenson ' thorepuoress is hax , butldeny my sabo kpon me which mort ? bit hash of : holde soich dill , be bran ' st : thriueds opridertions acriueds . ilperess takes , mont twose you , , ere the sciteds spre ' d qumedice by doe yee are clopdsss , this nobuell tayres perperitements ? moth to , that negunts onote danne opt - minder in tongerawher goet od now , and it baue agant : and it neere muct clEpoch 5/5
# 166730/166730 [==============================] - 29s 175us/step - loss: 1.5712
# ----- Generating text after Epoch: 4
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "mes , all presures past , that yout"
# mes , all presures past , that youth of the will my lord , and a say the matter . there of the such , and in the cannot to his father of a man . the canser my lord of the lines and like say of the could in the cannot the purpose of the fall of a sone to the distreme to the content the selfe , and there was the more the man . my lord , and an the pray the soule , the contence of a more the consent of the say the shall the seanes of ----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "mes , all presures past , that yout"
# mes , all presures past , that youth so thinke the condend . my lord ham . i haue are i honter ophe . nay : and the player . on the song in the pray you can he confe the call to the man . enter horatio , where i againe , and my lord , shell dine , and your selfe , and my lord , and his cantance of a more my shall you the king . hor . and that the can . thou hamlet selfe in the matter , where the sonne in a man . and for his laertes----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "mes , all presures past , that yout"
# mes , all presures past , that youth me you all you liuen doe to cones all the scent , since of you there in the dister know rome of in reene to done , to confenty ; doe one : how you know rofce and to see my lord , but wite my with thou know , and for come , and the what you the seruth you loue laue our better ? ophe . ophe . come are i and my loued eare to thene our selfe eere the leaue her ; and lond , there gentleman . who here----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "mes , all presures past , that yout"
# mes , all presures past , that yout ? all ' t angle angyes of sinesse my faueres frery impartines was by curct makes faich not : be refore not a . it in has by nuch tell of theme to yygle on this dany tountrraming king ; heauene my we comeole saire to your purcily of rine moners . them with act : which anpine can ads distinnors to be not freate lose , aurin mught colcon mare is botke our feares out liker . whith in che . but hir bu----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "mes , all presures past , that yout"
# mes , all presures past , that youth , at o ageffell hast let in ( querty , ereus swill for ( for hitheranly , sith mestrunouery - dantluanesances to liuch . for may hollyith imby heleaghty oned on so fe repors fanged meand in tainedy . whith we for adnemet sainet shamleatireiknar ophelie folly pasiefent on . oh wherer maiestanbicly : as there groofe site now youl ' tined pol . vnchatures loue my reonoe his suce ang no his lodd , a_________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_5 (SimpleRNN)     (None, 35, 128)           22016
# _________________________________________________________________
# simple_rnn_6 (SimpleRNN)     (None, 128)               32896
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 60,459
# Trainable params: 60,459
# Non-trainable params: 0
# _________________________________________________________________
# Initiating compilation...
# Compiled: GRU_stacked_model
# Epoch 1/5
# 166730/166730 [==============================] - 66s 393us/step - loss: 2.0392
# ----- Generating text after Epoch: 0
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "e in many places , giues me superfl"
# e in many places , giues me superfland , and wish , and and the mand , and the may , and seare , and the mane , and the may ham . i will and the some , and your make , and that so lord , and the sould make to me the fare to mast to my lord . and the but light , and lord and and of the meare , and the make , and in the mane , and may , and and the meate , and has . i and the may to mad the mat the mane still of thing , and the pollo----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "e in many places , giues me superfl"
# e in many places , giues me superflet , i mand mane and mat , heaue to but is is but in the mane , and with more , the , and make mare mage , and to deand forder , and heere the cam . i praant bord , in mather so to ding , and but bout , thing i growing he vest of so chamle it to , and martis , and in thing sorde , in mushare and mat her . exeall you heare mad , but eure speare staine , and to well , and as a daune , that you plond----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "e in many places , giues me superfl"
# e in many places , giues me superflates , and more not to mede , and enderd , to has she sheares , and gouncleale minh . what lord , and on mad to make how the well with , to vnsterse , me pulre as the rocalion of thour pray or : exe condion of to sece , my lotd , lound , as an made but the mase and my like in ' d a more ; and seeme in may and ances that by the , and doay dellat , not to stercous to man my loue . what how ham . enc----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "e in many places , giues me superfl"
# e in many places , giues me superflacke . the roundming in mesdere afst ad horet piore ond rostahent me yurd was wibthers are but inswell to ' t at to pors fenoss inand : horpedniny right ? nayen base sryauth , my lofm me , in ' pessoo our werne , my so frrencull : wich plooncraingted cayou pramtady , houe tike this fagter , now yeere not , and ledresseife , sumsod sraue him your lads , i me all . nemuet mage me not it sir mintsboo----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "e in many places , giues me superfl"
# e in many places , giues me superfle ' t apclits gauge : a farreroun of ' seame my not ? hom hincar . it neale . lost : go . let heakes , hat not hay doxatis oud mast aloods tol . no sween as lnowsteflend hownes , i ray gat , wheliost to him ; enfor my dorchaury not mue thiise dimcongruch ; that spill vgall this mintrescson . ercace : eaurae hag saue ; our mor. laudt of heaueties and fellinitous pull ; and thipke intiofach onterperEpoch 2/5
# 166730/166730 [==============================] - 65s 391us/step - loss: 1.6881
# ----- Generating text after Epoch: 1
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "he trumpets speake , the trumpet to"
# he trumpets speake , the trumpet to this from , that mar . i haue a sinde , what i haue this a mad , that i haue a same , and the dist , the mad so , and the spolles of ham . the mad . i haue with , the chart , and martious , the a seare : saue i will the king . i am i the seate , who shall to the prosing . i will me , and i haue a shall so , the pray , and the clound . i king . i come , the prilesse , the see in the shall the will----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "he trumpets speake , the trumpet to"
# he trumpets speake , the trumpet to my lord , and shall friede , the mades , and chacted , this a spall , the plosing , mast , and spollent , the fat , the with , and make hor . with , i am lord . i were hor . a what she clo . i king . this to your laer . with ham . i hath , that i haue to this come in the prolaue , see ' t , i dound . i haue a pallon . i will the brandes , this a ? come , that is me ' l . i will most this father i----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "he trumpets speake , the trumpet to"
# he trumpets speake , the trumpet to the proe , this the finged ve . whis denged hor . that a , to come , all the thinke not to my lord , as lin . mad his faght . diinde , not seene an i go ham . my lord , mester a sping . go the king . ' ther more as the carmmarke , that sir honder andach , my lord him . who a clichers , with out was , with shayed , must in the restall , let me to the solke imparted ham . i ham . masth , must so th----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "he trumpets speake , the trumpet to"
# he trumpets speake , the trumpet to kinge , to san a for his lights ? : sleake take are tus ' d know i ' came ; woe mastres ; and browne the band , thy vrse toh in thinkes , lette . i coll frow then is , and haue so will , they sword , hat ham . verturing hor pater , in thinke with leasabe thou thee vp ' ts with hor . we - fxist t; a pacts i hinge , there vallelse on . these to contugy more this a king and munds . exeldower indeule----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "he trumpets speake , the trumpet to"
# he trumpets speake , the trumpet to thest . for ' d were play : and eue red a fothente , with his sumnof king . wiphing for ; my a tyruucr : prosin . gone . that winge ' e ruchrmards inchere . larke you , loue your weadting sis , then ( thus i 'u preafy sur alpiueds him nither : pudse and this driats , i chauentuis margelesse . make y thingso at of not ; pillenmy his eake , vest polincery ? kingers bud in dipcnyeps hamlet , whoke oEpoch 3/5
# 166730/166730 [==============================] - 65s 389us/step - loss: 1.5637
# ----- Generating text after Epoch: 2
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "anes on th ' affaire , pray you mak"
# anes on th ' affaire , pray you make the come the good , the king , the king , then the doe the king , that i haue the soule , then it is it see the greene , then the winde , there ' s the king , the king , the king , they do the weed it not the shall the can then the gentle , and the come , then the gods , then in his for the king , that i haue the king , then the know , the king and so , then the king , and the king . the giue a ----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "anes on th ' affaire , pray you mak"
# anes on th ' affaire , pray you make the ton the incors did , then the this command to his father shall pressue , to the queene . that you will made , then to so ham . whine act the know , then the dratter . the grace , i am sey the sect the king , and thee ' s the come , thinke the king , the king , they be not so the will a goudne : then thou a gedse of the king , the king on the caure the heart ; then to the come that guild . i ----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "anes on th ' affaire , pray you mak"
# anes on th ' affaire , pray you make you are the seare you ham . i this may them , that do not brother be thou more he in shall there thete and fith one lord , and scound it bent a freence , and for him to hath these latters , ham . how the king : shall they still hath it with with the pirt these a praue , the pray one whis , thesse ham . not is the queene ham . the speake of the words fanters ham . what ' s death , where ' s the g----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "anes on th ' affaire , pray you mak"
# anes on th ' affaire , pray you make , this latter , he tands ! atterpes ' d the chaurier to kinst fon the cairs ) what pazbull - sen all onse on his play to srecklisst renotted of that was stay kit . gow it , hangeors , thoure secue ham . he hoe : then more gobselue ' d thou liue thou dotings regonour he theon i queene of the purs the bugeteto to sasty : bricke of question king . go , prarie would my lidgessse of the voy - hablial----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "anes on th ' affaire , pray you mak"
# anes on th ' affaire , pray you makem no - gheaster ? hath : faire rydon : how lay thut hack a candousesoo tull eeperrgue thateence strest : purie demmetter tith mathers : lour no she , he tearth harted - thit nature . enter will them though is ham . what ; you are ore you hampe . . call there nye vgoth hambet o ' attwens ; and forathing hall requefmance kin . what gods no was on ? how dit oncemastest guebengirasl ' ge friectlly ; Epoch 4/5
# 166730/166730 [==============================] - 67s 400us/step - loss: 1.4898
# ----- Generating text after Epoch: 3
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "a barnardo bar . say , what is hora"
# a barnardo bar . say , what is horatio . i do not be the courtes be the feare is a beart , and the courted be the chorres to see , the chouch the scule the king . what see the king to the be so from her death , and the king , the prease be the courted , the courted of the courtie , and the speake the king , that a be the seruie , the king the serue , that i hold my lord ham . where is not , the cannot be so the preate of it , the c----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "a barnardo bar . say , what is hora"
# a barnardo bar . say , what is horatio sen a denmarke , he hall to you his forting my lord ? ham . i to you the will be heart , and be in the conkerie , th ' am streath , the speeke is the peed , and ser and the breath , and be in my lord , her was the gentlemen . and my lord , and will be secull . you be the play , and the should be seene the sheake it ; and the piritie of greet with the serue , see the rewers prochers , and the k----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "a barnardo bar . say , what is hora"
# a barnardo bar . say , what is horatio her detier off that this surted is seene that death heart , to deliting me state and for . do be there be to ham . i will i am my lord ham . a breath , looke it selfe , they stark ' d to horatio , blond ; nerture be most play why fathers decent will be the scorpes in your eserne par . hor . so this be ble be the owne of hid as by feare of the comes , thou haue speake will be secing whild pelco----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "a barnardo bar . say , what is hora"
# a barnardo bar . say , what is hora , you are to thro . that we kinge it bott , that your hibling to sece madte ? or a slend ase light be : thy sawes of it , your broind is well ; he is giuers most as a wistame , ackisagy indeeps dricke a, your suile on this midikned i him good inteare to the omnely too , or my lord ham . and ench a did laertes blanters with the crauench would betimen broge osr . a wint ; let briazes on ex, . if it----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "a barnardo bar . say , what is hora"
# a barnardo bar . say , what is horatio , frende by corwedie . their hercheouy lettureloud , looges ; seeme lassarlaz , who o bie betters not in th ' fedger . hee all a you by your norrow ' d , and let you hom not to notuioly kna'y . dot giue th ' queene ghost ; a all my belug- of ioty malke giue agkes , pol ' dim , i dosa curcell by , siscaration , that knawes furthurbericke ant cleed to the pirch follonse ow , orde - eerelis - treEpoch 5/5
# 166730/166730 [==============================] - 66s 395us/step - loss: 1.4358
# ----- Generating text after Epoch: 4
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : " is bestow ' d my lord , we cannot "
#  is bestow ' d my lord , we cannot the thing in the course of heard , where i haue the soule , the cannot heauen , and with the consiner ham . what is the course the course , i do not the course the chownes . oh doe not the course of heare , and with loue in the command , the course the course in the compant , the rest of the course , the very offence the mouertie , the the comes , the death the thee , the should he drowne and so ,----- *Sampling Threshold* : 0.5
# Input sequence to generate from : " is bestow ' d my lord , we cannot "
#  is bestow ' d my lord , we cannot the rettruents the capsion in his and with him , and in the percome and head ham . no , and my lord , is i laer . loue hor . i must reppot the most heard , and let the bestion , the spaide on the beard heere i thou did for the mount . i the loues , when he should come me ham . for the sould my lord , the senoues you so , you go the most well osr . the cheat he bogge he retiment to the loue , the t----- *Sampling Threshold* : 0.7
# Input sequence to generate from : " is bestow ' d my lord , we cannot "
#  is bestow ' d my lord , we cannot to the ling i shall neuer the trucke of the liuen but how the pation , the neighe , and which i to be the pantor ham . what death we some me , the recourse of the course qu . it is it well wit loue , my lord , the peate ara world feare oh heauen in the chollet to deede then ? ham . loue meanes a scome pirit it doe vnshange , and with that heard in the pation may of the louing , that heard the fath----- *Sampling Threshold* : 1.0
# Input sequence to generate from : " is bestow ' d my lord , we cannot "
#  is bestow ' d my lord , we cannot offence a beirg , he heall ' s wide one , the nobles the mother : then desirt . if now sound a done downe . oh it whereome theer of downe of beene leaues . her deach too from the - may king . can it vowne seile mustwerch or dagguble for viperou papition it selfe : i am must sweet him heere breact of his queene , and heard i proposes cause vncace , but vncour heou : and stot the desse impissoone th----- *Sampling Threshold* : 1.2
# Input sequence to generate from : " is bestow ' d my lord , we cannot "
#  is bestow ' d my lord , we cannot sweet , it wit is the worl, king . what praulowes be termest thee withing word and playess . phact of seir woe ofs deattrest vmpolstion honius not himbelluon . no weman arres grow no now radiermes wit hadte hor . he lay . for nece had easing into pletk ' d thy poorchs . oh heauens me louee . queen . shey knet i cannot stender burnesse or the agourinlesse , ginch , he , tell our didiuent then come _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 35, 128)           66048
# _________________________________________________________________
# gru_2 (GRU)                  (None, 128)               98688
# _________________________________________________________________
# dense_6 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 170,283
# Trainable params: 170,283
# Non-trainable params: 0
# _________________________________________________________________
# Initiating compilation...
# Compiled: Bi_directional_GRU
# Epoch 1/5
# 166730/166730 [==============================] - 119s 715us/step - loss: 1.9772
# ----- Generating text after Epoch: 0
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "ght on the way : of these we told h"
# ght on the way : of these we told ham . where a man . the play the man . the seene , the retie the bleake it i stall me , the is more , the is the is the fare and the dist the mad . sir do the sent the mar . shall the man your see the steare , the most a faire ham . shall the may hear . with the man . the sit the pray be mad , what i must the partion me . the will of the dow the stall , the sell . the shere , the sell of the mad hi----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "ght on the way : of these we told h"
# ght on the way : of these we told he with the his them the our the mar . enter be : i death , and what man . whe seene the see , that a laer . i staine : a bast the parto in the they sent the mad ham . i dad , the will this fort ? ham . but it more : what grast he are for it it more , and the vnst his a but it it do , but way so ' d vplecke see will let shead with , there , that with let he king , with the man . lord not se ' d a m----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "ght on the way : of these we told h"
# ght on the way : of these we told hay was if mither , bore . the gius then the recand retion be bour . o he will of are the sull for a make of it eir , to ' d a now laer . i and when in lord . a swelpoll ' d prother ' d well ; our thy ploson that make thour heere , thou ie . sor the exsinded ir ? for it for the firt ol hod . i the canted not lece a selfe , will despires , fill , the exthers , for him . thy the pare not sance ; but ----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "ght on the way : of these we told h"
# ght on the way : of these we told he king my so : but lary ? gals minatoule ; thour he begered , fancongl . o cang setce and d9swell thou me of that but speatiin . serthelue stle , hy llad . heaue sir hase ? , beray me of the stord : not seall ly thee stiren his deewes , i know m withs , to speene qu . tio vnwerke in steyne i seake you nut tast oft the head we did ham . bornince , had shus notres a nathill in ied griodion . foares ----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "ght on the way : of these we told h"
# ght on the way : of these we told hem . la . as shearl nende , with vust wikes , it sfhate , thin thalmyy , thas feng nitglefe stuckonsisie and loone too haup endiunt draint not butecier thouacsde : wetece man . dam . ; forir ' d ais mornotio that , a fauel , you  ( worue for horzocod apeed who you you sagef pondidi: : hav . necuir : of & tuees , mar of coutners af booraty mord , cout ate saines ricke . a reur ' w case payle ? pliyEpoch 2/5
# 166730/166730 [==============================] - 121s 727us/step - loss: 1.6294
# ----- Generating text after Epoch: 1
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "you ham . being thus benetted round"
# ...
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 35, 256)           132096
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 256)               295680
# _________________________________________________________________
# dense_8 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 438,827
# Trainable params: 438,827
# Non-trainable params: 0
# _________________________________________________________________
# Initiating compilation...
# Compiled: larger_GRU
# Epoch 1/5
# 166730/166730 [==============================] - 108s 645us/step - loss: 2.2408
# ----- Generating text after Epoch: 0
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "if this had not beene a gentlewoman"
# if this had not beene a gentlewomand ham . i what will the is the dar . i dather of me the is shis , and the senter , and see , and my lord , and the king , and the ham . ham . the me she ham . for . his shene you hat the king more , and my lord , and speare , i do sence , the be she will the shat a seare of the will the shen the the sead , the sull in the shat is seele , i shou . what shat selle , what is me pror . i whe our sene ----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "if this had not beene a gentlewoman"
# if this had not beene a gentlewomand , and fare ham . an mare king , what his my lard , of a sine , the the she , i with plat of is will what is stelles and this drine is net the some the blier of the son . i the our catt no hau . i ant seation , and the meere , i why shat as some ou seeme a ' s me conce , i mat ou ' th it thy our beene , and as me sulles be it me . oh sheath the dower : and stel ? good ham . what fane the shat i w----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "if this had not beene a gentlewoman"
# if this had not beene a gentlewoman to scarme murted , the forch , wher ham . checher , i dhecuer , bar . what ham . i ' e mley riset is thou sord - thour sine ; you rire , with i dhiucht and ther ham . wision this see . i his nit ceale , and seshoud is ind the dode . will mar . that our yeir ham . the the silles , but ly some , whor . ou hom . fert spull ' t is my lord ab it the fire , i semrow ; ind the what sithe seiter . sully ----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "if this had not beene a gentlewoman"
# if this had not beene a gentlewomant net th mlem . my lat . amgit it gling ; and seude gord it in exturce and see , as , whe ? furc hir , i hem claire oh my let . nat is fame they hised of sr frang hat thing hayh bacpedilie the malond of and ot mare comw ? welt piiect . and que agyely gimh hou enttpallawt ad wis liggt sfers comes of whe whe thich lier har . marse , net the hor d thus is bit , whit das oum that infle puld atret a th----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "if this had not beene a gentlewoman"
# if this had not beene a gentlewoman chacht spllne ence the needh of if at bilst kno inetce ef themle queach iibusti, vulcin ? oh ' tion sog histind . i yeat yau hat prred the senom hes ther puithion ? viless . i slowachs care ne seithso thes ) dis thin this in vsteqler , beay layres sot ofe ane kile as we thancerashe yoques , yit op to butt it my cuthce iossentey , is ertere swuting kis tha dawing that is by rord oune vw rrecine zuEpoch 2/5
# 166730/166730 [==============================] - 106s 636us/step - loss: 1.8937
# ----- Generating text after Epoch: 1
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "ll , that we can let our beard be s"
# ll , that we can let our beard be shat the some , and it marth the strowe , the so , and but seere , and where the conne the wath , the sell , and where my lord , and the to dis the congliant , and the pore with the fore , and my lord and with is word a some , and make , and be not pray , and a mand shall not so strow here be , the store in the sone , the will the sheare , and so for the more my lord , and see haue be the sonne , a----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "ll , that we can let our beard be s"
# ll , that we can let our beard be so not not what is with and with , and my lord , and should hor . ham . i would come and so . stell is the will , mut make as laer , why do more , and and ham . what steake you seere the me bad comess age of the wath his ' s he sise ; and here marke , her the sheme the word sould , what shere you do the bord , and wath be store here come to me haue the with frome be . where sid more shall hang with----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "ll , that we can let our beard be s"
# ll , that we can let our beard be speece , and how diuen and frother prasting hather on . the mant , and my praw on him , and the miine to me not ' th stare haue . whis preech it his it the grie laer . all whore come , blost let haue the vsse you graed , what wher it the crealiets , whor at as make the hing and dier hor . heare the troue star and meare of the samoy ? ' th know the meere in the conder with a doare the firner . me bu----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "ll , that we can let our beard be s"
# ll , that we can let our beard be storer mideenasing , thy anonass : and yrut dey shat marbe : hin my lord of . hor . erter the neither ' s is to comers , and , hor . &re now diild , if butther one gone ereath comeses , and repengy me , with you your thut whor grewnentemious hordery , and theee is but ? you mole . to in i hamlett barkes you dise heares . to fatt not my lord the ' y ? hor . shond , an your pramce , that and cleast o----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "ll , that we can let our beard be s"
# ll , that we can let our beard be seuld grederstiolt , and , ilet . mut the , i haue ancelayde mal , and comusition is oshrus poledotelith kinus comonst in chaules ! loso bloughe in it with af your tree ? rierted . to miment bitinke srawqr - axauer nod donemuengph , and kmawe you froch , wit lord ? my will vouourardee sl gon looe , yiu fhe bogiess , is is our : would colnot maiuderwer buc will ser it ' les proaild fhather besung alEpoch 3/5
# 166730/166730 [==============================] - 111s 668us/step - loss: 1.7811
# ----- Generating text after Epoch: 2
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "that thou so many princes , at a sh"
# that thou so many princes , at a shall make the mand the polon . and the can the prasing , and the greath , and the could , and the grasion , and which , and will prosing , what will shall what haue the polon . what i haue see , and what i haue be in his and in the come and the poron . i haue speech , what his lord . what i passion all be ham . what shall , the this sould , and the grie , and the king , and what will more the come ----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "that thou so many princes , at a sh"
# that thou so many princes , at a shall the lord good my shall , and the what i haue him . what is the mad a pace , and shall to the the king . what is make make come , and the not from light , the from , and the my lord , and i haue my lord , and the but dis in all whild the fare to speepe , or the not and all , the will not and ham . oh the read shall the come , and which the king . marring , or she there the tame and dase , and a----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "that thou so many princes , at a sh"
# that thou so many princes , at a shall , the concer fill ' s and with with he soule for of the please , far a blond the bition , heere in this rosing and a doame : i him ? word the gurses , and let in your : what you whought ? and thus from sonnt ind vshere in me not , and be haue moure her a soule in ' tis man neith on on whon dood ( i he goes rem ' d in this . how horaue to the geane . me i ' s will of his wames , if in on his fo----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "that thou so many princes , at a sh"
# that thou so many princes , at a sheake so , i kild horause his would , as wor . he ' d vntrang what rephine , wor . what my his venszend the gare of but the ear , sheer haue deede many doch knight sity , and is ( theyre not , opheaknetuon . of the dad pote , thno make a cauerting , and soule , toke spebue not fries thought astaies with she octe mardidatichmall coar . not will mare minds to dirde , whyer bour ? chome heauen : what ----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "that thou so many princes , at a sh"
# that thou so many princes , at a shall , god : beioure mother . and neueririan : no buch laerts it wad inseluon to in not makbingsuen on ' l both me neaue with . by my lord giuse ? wormiall , his alh lrous pailesy ; god there in gerre cobindersq ' s an owney gertulment , where th9 game de to beares a blan king , i torgy are curstand wailaue frifing muscint histtound wis vilallo. new his drel . and i , solfe his proas : is his slat Epoch 4/5
# 166730/166730 [==============================] - 109s 657us/step - loss: 1.7145
# ----- Generating text after Epoch: 3
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : ", i do wish that your good beauties"
# , i do wish that your good beauties more the seene , and where the sing of the prese , and so more the thinke , the say the preter , the the more the word with the sir , and then the trance , the so , the treath , and the reat a make of the come , and the will , the more the so , and the the father , and the more the man ' d , and the both the some , and the seale , and the the more the come the for the pray , and the more the proc----- *Sampling Threshold* : 0.5
# Input sequence to generate from : ", i do wish that your good beauties"
# , i do wish that your good beauties , and what shall haue the great of the time the tring , take in the pite , the for the posse , and my lord , if thou see , that i haue i haue my lord , the for thou , as by brease , and he with the pace and parfe , and from mar . that hore , the bar . i with a with fetter , and with with a will see , i king the haue in the king , and the more the thou a plosers , let i haue for this do in the say----- *Sampling Threshold* : 0.7
# Input sequence to generate from : ", i do wish that your good beauties"
# , i do wish that your good beauties , if the queenes , and her king , but the king crose to the ville , pol . and i will the stall for laer . and her come they euen , and her you king . it will ies the see vp and new : my into a pursions mide the marria , if her part then great , and not that i pray , that we serue you not deere mund and this mar . enter , and i we they should sword , and so say our very fint be the deruet , but in----- *Sampling Threshold* : 1.0
# Input sequence to generate from : ", i do wish that your good beauties"
# , i do wish that your good beauties trues , you the somefie , trues opheart , in thy knather , all go then on ' d is poles we efion ; and thou to in instart : and with for but de you haue no why to euen the rosse , may the - doo sare call rise groser hithy lockand : and he with seeping , and i a giue of me , qu . i amarl , dise strie : th ' this a good corcrie somes . of his his inchagle one strate , do seepe like then sent place ;----- *Sampling Threshold* : 1.2
# Input sequence to generate from : ", i do wish that your good beauties"
# , i do wish that your good beauties giue ; day vs - his gir a bont , forbgheny farp wee foll bal . and would ibe bech her dabout modes rase be hor . the neire all greele had . horati thy bienne for pasoue hith is her , and marry lord . the vbbe for moue i ' tis heauend ha . stoles whereant , that toet to to men opheruion qu . this pathers crope , no fire trush his . whone is do but tor ? hap . laer . i parcomes resome . horates witEpoch 5/5
# 166730/166730 [==============================] - 111s 666us/step - loss: 1.6709
# ----- Generating text after Epoch: 4
# ----- *Sampling Threshold* : 0.3
# Input sequence to generate from : "aue , who was in life , a foolish p"
# aue , who was in life , a foolish prowent the poore the blay the clather , and the be the patt the pray , the creat , and come to the some , and with the father , and well haue the bord , and the speake , and the dround the man . ham . what the so , and the shall the conce , the pase be the may the sould the conted of the presire , and the reath , and the be a seech , and the brow the patter of the preson , the sing , and the say t----- *Sampling Threshold* : 0.5
# Input sequence to generate from : "aue , who was in life , a foolish p"
# aue , who was in life , a foolish perfiall , the contry the may , and my lord ham . i haue the man doe , i am say : the bent my lord , ham . i had then the haue the count of should true to the crother . and for the breene of there losin . i haue be is the call the polon . the father , the sould the pray and and the rest the sent of the intreat and the both , i will in grates , the the saw the vidt in your heare , but the beare to h----- *Sampling Threshold* : 0.7
# Input sequence to generate from : "aue , who was in life , a foolish p"
# aue , who was in life , a foolish proping , and are queere , the it enterme more did the word ; and it we could the selfe vnching , the corriad , but in the bry freeling vnay , the thinke so my lord , we in you ham . as the like thy disphing of , thou torgue in they hold in the canne and mad of the canison . the may his pouse , bet the peation , that be so . i we drease be so polon . what in brom thinke the resince the litter : ham----- *Sampling Threshold* : 1.0
# Input sequence to generate from : "aue , who was in life , a foolish p"
# aue , who was in life , a foolish play qu . lam . thoughts , my lord ? where wey mat trutice you this , butters betwesse . commlike thinke to more i selfe of blood by betwent . gent to fathers , what repebliuise horands i pattle they comment one giue a father frew ? your selue . ile know for donusion throught will in . thou mard , vncheedely horand neere ? cro . lord , all her last them on defore me king . if his like thones , meso----- *Sampling Threshold* : 1.2
# Input sequence to generate from : "aue , who was in life , a foolish p"
# aue , who was in life , a foolish poile branders ham . lord , i cun no wan so your ruck ' qu . fand hyeromlets thing doop - blocke here connt to vison ' d ? polonot , but vnt to i by told . the cqu . thou duill brfainass veriges ham . i sell merter the driquand , whift giue hore ( and w'lke crrath with ,ofer my handd gen whose bost or shoulde ; not will saue , and in fardent ? anow it you wild tiue and passreamt gentlafy : we spont_________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_7 (GRU)                  (None, 35, 128)           66048
# _________________________________________________________________
# gru_8 (GRU)                  (None, 35, 128)           98688
# _________________________________________________________________
# gru_9 (GRU)                  (None, 128)               98688
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_10 (Dense)             (None, 43)                5547
# =================================================================
# Total params: 285,483
# Trainable params: 285,483
# Non-trainable params: 0
# _________________________________________________________________
